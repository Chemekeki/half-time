# %%
cfile=("/home/dark/Desktop/machine learning/season-1819_csv.csv")

# %% [markdown]
# ### WHAT WE WILL DO
# We will try create the probability of a team winning a game if it was ahead at half time.
#
# We willl use the 2018 -2019 season to create this program.

# %%
import pandas as pd
import numpy as np
import pylab as pl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv(cfile)

df.head()
# Out:
#   Div        Date      HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0  E0  10/08/2018    Man United       Leicester     2     1   H     1     0
# 1  E0  11/08/2018   Bournemouth         Cardiff     2     0   H     1     0
# 2  E0  11/08/2018        Fulham  Crystal Palace     0     2   A     0     1
# 3  E0  11/08/2018  Huddersfield         Chelsea     0     3   A     0     2
# 4  E0  11/08/2018     Newcastle       Tottenham     1     2   A     1     2
#
#   HTR  ... BbAv<2.5  BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  BbAvAHA  PSCH  \
# 0   H  ...     1.79    17  -0.75     1.75     1.70     2.29     2.21  1.55
# 1   H  ...     1.83    20  -0.75     2.20     2.13     1.80     1.75  1.88
# 2   A  ...     1.87    22  -0.25     2.18     2.11     1.81     1.77  2.62
# 3   A  ...     1.84    23   1.00     1.84     1.80     2.13     2.06  7.24
# 4   A  ...     1.81    20   0.25     2.20     2.12     1.80     1.76  4.74
#
#    PSCD  PSCA
# 0  4.07  7.69
# 1  3.61  4.70
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of     Div        Date      HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0    E0  10/08/2018    Man United       Leicester     2     1   H     1     0
# 1    E0  11/08/2018   Bournemouth         Cardiff     2     0   H     1     0
# 2    E0  11/08/2018        Fulham  Crystal Palace     0     2   A     0     1
# 3    E0  11/08/2018  Huddersfield         Chelsea     0     3   A     0     2
# 4    E0  11/08/2018     Newcastle       Tottenham     1     2   A     1     2
# ..   ..         ...           ...             ...   ...   ...  ..   ...   ...
# 375  E0  12/05/2019     Liverpool          Wolves     2     0   H     1     0
# 376  E0  12/05/2019    Man United         Cardiff     0     2   A     0     1
# 377  E0  12/05/2019   Southampton    Huddersfield     1     1   D     1     0
# 378  E0  12/05/2019     Tottenham         Everton     2     2   D     1     0
# 379  E0  12/05/2019       Watford        West Ham     1     4   A     0     2
#
# ...

# %% [markdown]
# # Above is a view of the data of each game played in the premier league
# We will now try to estract the games and their half time/ full time statiatcs

# %%
dat=df[['Date','HomeTeam','AwayTeam','HTHG','HTAG','FTAG','FTHG']]
dat.head()
# Out:
#          Date      HomeTeam        AwayTeam  HTHG  HTAG  FTAG  FTHG
# 0  10/08/2018    Man United       Leicester     1     0     1     2
# 1  11/08/2018   Bournemouth         Cardiff     1     0     0     2
# 2  11/08/2018        Fulham  Crystal Palace     0     1     2     0
# 3  11/08/2018  Huddersfield         Chelsea     0     2     3     0
# 4  11/08/2018     Newcastle       Tottenham     1     2     2     1

# %% [markdown]
# # We will describe the meaning of HTHG, HTAG,FTAG,FTHG
# HTHG-Half Time Home Goals.
#
# HTAG- Half Time Away Goals.
#
# FTAG-Full Time Away Goals.
#
# FTHG-Full Time Home Goals.

# %%
if HTHG >
